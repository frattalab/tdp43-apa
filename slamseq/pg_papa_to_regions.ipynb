# %%
import pyranges as pr
import pandas as pd
import numpy as np
from helpers import get_terminal_regions, _df_update_3p, _df_update_5p, add_region_number
import os

# %%
# Prioritised Zeng et al. target genes with PAPA annotations
zeng_targets_papa = "ARHGAP32 CNPY3 RFNG SIX3 STMN2 TLX1 SLIT3".split(" ")
zeng_targets_papa
# Out:
# ['ARHGAP32', 'CNPY3', 'RFNG', 'SIX3', 'STMN2', 'TLX1', 'EGFR', 'SLIT3']

# %%
outdir = "processed/isoform_specific/regions/"
zeng_bed = pr.PyRanges(pd.read_csv(os.path.join(outdir, "zeng_pas_fig2c.updated.bed.tsv"), sep="\t"))
zeng_bed
# Out:
# +--------------+-----------+-----------+------------+------------+-------+
# | Chromosome   | Start     | End       | Name       | Score      | +3    |
# | (category)   | (int64)   | (int64)   | (object)   | (object)   | ...   |
# |--------------+-----------+-----------+------------+------------+-------|
# | chr1         | 629997    | 629998    | MTND2P28   | .          | ...   |
# | chr1         | 630367    | 630368    | MTND2P28   | .          | ...   |
# | chr1         | 854387    | 854388    | LINC01128  | .          | ...   |
# | chr1         | 859444    | 859445    | LINC01128  | .          | ...   |
# | ...          | ...       | ...       | ...        | ...        | ...   |
# | chrY         | 19691944  | 19691945  | nan        | .          | ...   |
# | chrY         | 19692490  | 19692491  | nan        | .          | ...   |
# | chrY         | 19703866  | 19703867  | KDM5D      | .          | ...   |
# | chrY         | 19705419  | 19705420  | KDM5D      | .          | ...   |
# +--------------+-----------+-----------+------------+------------+-------+
# Stranded PyRanges object has 16,101 rows and 8 columns from 24 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 3 hidden columns: Strand, gene_name_common, pas_id

# %%
# load in BED file of PAPA cryptics
papa_cryp_bed = pr.read_bed("data/2023-12-15_all.last_exons.cryptic.bed")

# get le_ids for cryptics (+ their annotated partners)
# e.g. ENSG00000213468.7_1|FIRRE|bleedthrough|cryptic	
papa_name_spl = papa_cryp_bed.Name.str.split("\\|", expand=True)
cryp_le_ids = set(papa_name_spl[0])
cryp_gn = set(papa_name_spl[1])
print(f"Number of PAPA cryptics - {len(cryp_le_ids)}")
print(cryp_le_ids)
papa_cryp_bed
# Out:
# Number of PAPA cryptics - 284
# {'ENSG00000109472.14_2', 'ENSG00000105808.19_5', 'ENSG00000100299.18_2', 'ENSG00000228824.8_4', 'ENSG00000135090.14_5', 'ENSG00000145819.18_3', 'ENSG00000139767.10_2', 'ENSG00000081760.17_1', 'ENSG00000186615.12_2', 'ENSG00000108587.16_4', 'ENSG00000131375.10_3', 'ENSG00000231312.8_4', 'ENSG00000105808.19_4', 'ENSG00000132849.22_1', 'ENSG00000078269.15_1', 'ENSG00000066032.19_6', 'ENSG00000105926.16_2', 'ENSG00000065526.12_4', 'ENSG00000155897.10_1', 'ENSG00000254602.2_1', 'ENSG00000121904.19_3', 'ENSG00000152954.12_1', 'ENSG00000075035.10_4', 'ENSG00000151692.15_7', 'ENSG00000117069.15_2', 'ENSG00000066379.15_1', 'ENSG00000100557.10_3', 'ENSG00000101624.11_3', 'ENSG00000119912.18_4', 'ENSG00000035141.8_3', 'ENSG00000253741.3_1', 'ENSG00000244115.1_2', 'ENSG00000122783.17_3', 'ENSG00000204314.12_1', 'ENSG00000203546.7,ENSG00000129480.13_2', 'ENSG00000148814.18_3', 'ENSG00000127995.17_2', 'ENSG00000170579.17_1', 'ENSG00000066032.19_7', 'ENSG00000153094.24_2', 'ENSG00000121578.13_2', 'ENSG00000173818.17_2', 'ENSG00000118922.18_2', 'ENSG00000181090.21_6', 'ENSG00000173818.17_5', 'ENSG00000102290.23_3', 'ENSG00000128805.15_2', 'ENSG00000145349.18_3', 'ENSG00000149577.16_4', 'ENSG00000171984.15_2', 'ENSG00000119509.13_2', 'ENSG00000100060.18_2', 'ENSG00000105926.16_1', 'ENSG00000158169.14_3', 'ENSG00000188026.13_1', 'ENSG00000216895.9_4', 'ENSG00000179965.12_1', 'ENSG00000138083.5_1', 'ENSG00000138083.5_2', 'ENSG00000132485.14_3', 'ENSG00000153558.16_3', 'ENSG00000173085.15_2', 'ENSG00000232995.7_2', 'ENSG00000187951.11_2', 'ENSG00000137936.18_1', 'ENSG00000125676.20_2', 'ENSG00000142794.19_3', 'ENSG00000131375.10_2', 'ENSG00000214562.15_2', 'ENSG00000117020.19_2', 'ENSG00000129158.11_4', 'ENSG00000137161.18_1', 'ENSG00000117151.13_1', 'ENSG00000181090.21_5', 'ENSG00000128805.15_4', 'ENSG00000197563.11_3', 'ENSG00000139767.10_3', 'ENSG00000138138.14_2', 'ENSG00000135953.11_2', 'ENSG00000126767.18_1', 'ENSG00000104435.14_1', 'ENSG00000154319.16_2', 'ENSG00000153558.16_4', 'ENSG00000122254.7_1', 'ENSG00000115665.9_2', 'ENSG00000263956.8_3', 'ENSG00000242686.4_2', 'ENSG00000185352.9_1', 'ENSG00000092140.16_1', 'ENSG00000180182.11_3', 'ENSG00000121578.13_3', 'ENSG00000109118.14_1', 'ENSG00000185736.16_1', 'ENSG00000119912.18_3', 'ENSG00000171094.18_1', 'ENSG00000105948.13_3', 'ENSG00000128274.17_2', 'ENSG00000107807.13_1', 'ENSG00000156171.15_4', 'ENSG00000128708.13_3', 'ENSG00000026652.15_2', 'ENSG00000162813.18_2', 'ENSG00000164849.10_1', 'ENSG00000244405.8_3', 'ENSG00000148120.18_5', 'ENSG00000197724.11_1', 'ENSG00000186908.15_2', 'ENSG00000100557.10_4', 'ENSG00000100299.18_1', 'ENSG00000254602.2_2', 'ENSG00000115839.19_2', 'ENSG00000156171.15_3', 'ENSG00000124370.11_1', 'ENSG00000157500.12_4', 'ENSG00000164609.10_5', 'ENSG00000261879.8_2', 'ENSG00000127511.10_2', 'ENSG00000138802.11_2', 'ENSG00000162944.11_1', 'ENSG00000095203.15_3', 'ENSG00000188191.15_3', 'ENSG00000118922.18_1', 'ENSG00000235173.7_2', 'ENSG00000007047.16_3', 'ENSG00000128274.17_1', 'ENSG00000158604.15_1', 'ENSG00000004866.22_2', 'ENSG00000166135.14_3', 'ENSG00000066379.15_2', 'ENSG00000048649.14_1', 'ENSG00000132394.11_3', 'ENSG00000111450.14_1', 'ENSG00000186908.15_3', 'ENSG00000281566.3_1', 'ENSG00000227110.7_3', 'ENSG00000164038.16_1', 'ENSG00000198797.7_1', 'ENSG00000135315.12_1', 'ENSG00000198908.12_1', 'ENSG00000124370.11_2', 'ENSG00000028310.18_3', 'ENSG00000265808.4_3', 'ENSG00000127995.17_1', 'ENSG00000035141.8_2', 'ENSG00000184178.17_1', 'ENSG00000162813.18_3', 'ENSG00000169856.9_1', 'ENSG00000095203.15_2', 'ENSG00000247199.6_1', 'ENSG00000163964.18_3', 'ENSG00000183570.17_3', 'ENSG00000184347.15_7', 'ENSG00000122254.7_2', 'ENSG00000263069.6_3', 'ENSG00000197497.11_3', 'ENSG00000214562.15_1', 'ENSG00000132485.14_2', 'ENSG00000263069.6_2', 'ENSG00000149050.10_1', 'ENSG00000078124.13_1', 'ENSG00000028310.18_2', 'ENSG00000179796.12_1', 'ENSG00000101412.13_1', 'ENSG00000140750.17_5', 'ENSG00000204764.14_9', 'ENSG00000120868.14_2', 'ENSG00000166135.14_2', 'E ...
# +--------------+-----------+-----------+-------+
# | Chromosome   | Start     | End       | +3    |
# | (category)   | (int64)   | (int64)   | ...   |
# |--------------+-----------+-----------+-------|
# | chr1         | 15939295  | 15940456  | ...   |
# | chr1         | 15939295  | 15940477  | ...   |
# | chr1         | 177280411 | 177282422 | ...   |
# | chr1         | 177280411 | 177284690 | ...   |
# | ...          | ...       | ...       | ...   |
# | chrX         | 17835910  | 17837395  | ...   |
# | chrX         | 108267641 | 108269152 | ...   |
# | chrX         | 40653641  | 40654363  | ...   |
# | chrX         | 131823775 | 131825221 | ...   |
# +--------------+-----------+-----------+-------+
# Stranded PyRanges object has 284 rows and 6 columns from 23 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 3 hidden columns: Name, Score, Strand

# %%
# get Zeng IDs that are missing from iCLIP GTFs (+ add TLX1 which is misannotated)
zeng_targets_papa_missing = set(zeng_targets_papa).difference(cryp_gn).union({"TLX1"})
zeng_targets_papa_missing
# Out:
# {'EGFR', 'RFNG', 'TLX1'}

# %%
papa_gtf = pr.read_gtf("data/novel_ref_combined.last_exons.gtf")
papa_gtf
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      | Start     | End       | +17   |
# | (category)   | (object)   | (category)   | (int64)   | (int64)   | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr1         | .          | exon         | 24419290  | 24420128  | ...   |
# | chr1         | .          | exon         | 24421813  | 24422110  | ...   |
# | chr1         | .          | exon         | 24454053  | 24454824  | ...   |
# | chr1         | .          | exon         | 24464025  | 24466378  | ...   |
# | ...          | ...        | ...          | ...       | ...       | ...   |
# | chrY         | .          | exon         | 21880075  | 21880652  | ...   |
# | chrY         | .          | exon         | 21880307  | 21880652  | ...   |
# | chrY         | .          | exon         | 21038288  | 21039044  | ...   |
# | chrY         | .          | exon         | 23936726  | 23936831  | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 124,066 rows and 22 columns from 24 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %%
papa_gtf.columns
# Out:
# Index(['Chromosome', 'Source', 'Feature', 'Start', 'End', 'Score', 'Strand',
#        'Frame', 'gene_id', 'gene_name', 'transcript_id', 'exon_number',
#        'region_rank', 'Start_ref', 'End_ref', 'transcript_id_ref',
#        '3p_extension_length', 'event_type', 'ref_gene_id', 'ref_gene_name',
#        'le_number', 'le_id'],
#       dtype='object')

# %% [markdown]
# ## Clean up TLX1 and RFNG
#
# xx

# %%
# subset to novel predictions (never need annotated, so just overwrite existing object)
papa_gtf_annot = papa_gtf.subset(lambda df: ~df.transcript_id.str.startswith("PAPA"))
papa_gtf_novel = papa_gtf.subset(lambda df: df.transcript_id.str.startswith("PAPA"))

# %%
# subset to Zeng et al. target genes (+ TLX1)
papa_gtf_novel_sel = papa_gtf_novel.subset(lambda df: df.ref_gene_name.isin(zeng_targets_papa_missing))
papa_gtf_novel_sel
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      | Start     | End       | +17   |
# | (category)   | (object)   | (category)   | (int64)   | (int64)   | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr10        | .          | exon         | 101134174 | 101138530 | ...   |
# | chr10        | .          | exon         | 101134174 | 101138530 | ...   |
# | chr10        | .          | exon         | 101136690 | 101138531 | ...   |
# | chr10        | .          | exon         | 101136690 | 101138522 | ...   |
# | ...          | ...        | ...          | ...       | ...       | ...   |
# | chr17        | .          | exon         | 82045104  | 82048807  | ...   |
# | chr17        | .          | exon         | 82045147  | 82048807  | ...   |
# | chr17        | .          | exon         | 82045150  | 82048807  | ...   |
# | chr17        | .          | exon         | 82045423  | 82048807  | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 9 rows and 22 columns from 2 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %% [markdown]
# ### TLX1

# %%
papa_cryp_bed.subset(lambda df: df.Name.str.contains("TLX1"))
# Out:
# +--------------+-----------+-----------+-------+
# | Chromosome   |     Start |       End | +3    |
# | (category)   |   (int64) |   (int64) | ...   |
# |--------------+-----------+-----------+-------|
# | chr10        | 101134376 | 101138530 | ...   |
# | chr10        | 101136690 | 101138531 | ...   |
# +--------------+-----------+-----------+-------+
# Stranded PyRanges object has 2 rows and 6 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 3 hidden columns: Name, Score, Strand

# %%
papa_gtf_tlx1_prox = papa_gtf_annot.subset(lambda df: df.Start == 101136690)
# distal PAS can be plucked straight as selected in BED file
papa_gtf_tlx1_dist = papa_gtf_novel.subset(lambda df: df.End == 101138531) 

# now make proximal by overlapping with Zeng PAS and truncating
tlx1 = pr.concat([papa_gtf_tlx1_prox, papa_gtf_tlx1_dist])
tlx1
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr10        | .          | exon         | 101136690 | 101137789 | ...   |
# | chr10        | .          | exon         | 101136690 | 101138531 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 2 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %% [markdown]
# ### RFNG
#
# Problem here was a slight bug with PAPA grouping extensions together with the annot event

# %%
rfng_annot = papa_gtf_annot.subset(lambda df: df.ref_gene_name == "RFNG")
rfng_novel = papa_gtf_novel.subset(lambda df: df.ref_gene_name == "RFNG")
rfng_annot
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr17        | .          | exon         |  82047901 |  82048807 | ...   |
# | chr17        | .          | exon         |  82047901 |  82048807 | ...   |
# | chr17        | .          | exon         |  82047901 |  82049116 | ...   |
# | chr17        | .          | exon         |  82048444 |  82048807 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 4 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %%
# pick longest annotated RFNG PAS
rfng_prox = rfng_annot.subset(lambda df: (df.Start == 82047901 ) & (df.End == 82048807)).drop_duplicate_positions()
rfng_prox
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr17        | .          | exon         |  82047901 |  82048807 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 1 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %%
# manual curation suggests x is one to pick (s)
rfng_dist = rfng_novel.subset(lambda df: df.Start == 82045150)
rfng_dist
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr17        | .          | exon         |  82045150 |  82048807 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 1 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %%
rfng = pr.concat([rfng_prox, rfng_dist]).sort()
rfng
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr17        | .          | exon         |  82045150 |  82048807 | ...   |
# | chr17        | .          | exon         |  82047901 |  82048807 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 2 rows and 22 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %%
rfng_tlx1 = pr.concat([rfng, tlx1]).sort()
rfng_tlx1
# Out:
# +--------------+------------+--------------+-----------+-----------+-------+
# | Chromosome   | Source     | Feature      |     Start |       End | +17   |
# | (category)   | (object)   | (category)   |   (int64) |   (int64) | ...   |
# |--------------+------------+--------------+-----------+-----------+-------|
# | chr10        | .          | exon         | 101136690 | 101137789 | ...   |
# | chr10        | .          | exon         | 101136690 | 101138531 | ...   |
# | chr17        | .          | exon         |  82045150 |  82048807 | ...   |
# | chr17        | .          | exon         |  82047901 |  82048807 | ...   |
# +--------------+------------+--------------+-----------+-----------+-------+
# Stranded PyRanges object has 4 rows and 22 columns from 2 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 17 hidden columns: Score, Strand, Frame, gene_id, gene_name, transcript_id, exon_number, ... (+ 10 more.)

# %% [markdown]
# ## Generating bins for all ALE events

# %%
# remove tlx1 from analysis 
papa_cryp_bed_upd = papa_cryp_bed.subset(lambda df: ~df.Name.str.contains("TLX1"))
# pull out gene name
papa_cryp_bed_upd = papa_cryp_bed_upd.assign("gene_name", lambda df: df.Name.str.split("\\|", expand=True)[1])
papa_cryp_bed_upd
# Out:
# +--------------+-----------+-----------+-------+
# | Chromosome   | Start     | End       | +4    |
# | (category)   | (int64)   | (int64)   | ...   |
# |--------------+-----------+-----------+-------|
# | chr1         | 15939295  | 15940456  | ...   |
# | chr1         | 15939295  | 15940477  | ...   |
# | chr1         | 177280411 | 177282422 | ...   |
# | chr1         | 177280411 | 177284690 | ...   |
# | ...          | ...       | ...       | ...   |
# | chrX         | 17835910  | 17837395  | ...   |
# | chrX         | 108267641 | 108269152 | ...   |
# | chrX         | 40653641  | 40654363  | ...   |
# | chrX         | 131823775 | 131825221 | ...   |
# +--------------+-----------+-----------+-------+
# Stranded PyRanges object has 282 rows and 7 columns from 23 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 4 hidden columns: Name, Score, Strand, gene_name

# %%
# annotate prox and distal 
papa_cryp_bed_upd = add_region_number(papa_cryp_bed_upd.assign("Feature", lambda df: pd.Series(["exon"]*len(df), index=df.index)),
                  id_col="gene_name",
                  feature_key="exon",
                  out_col="pas_number",
                  sort_col="End",
                  ).sort()

papa_cryp_bed_upd
# Out:
# +--------------+-----------+-----------+-------+
# | Chromosome   | Start     | End       | +6    |
# | (category)   | (int64)   | (int64)   | ...   |
# |--------------+-----------+-----------+-------|
# | chr1         | 15939295  | 15940456  | ...   |
# | chr1         | 15939295  | 15940477  | ...   |
# | chr1         | 21453372  | 21457150  | ...   |
# | chr1         | 54634687  | 54639192  | ...   |
# | ...          | ...       | ...       | ...   |
# | chrX         | 108267641 | 108269152 | ...   |
# | chrX         | 123600550 | 123603748 | ...   |
# | chrX         | 123600573 | 123601338 | ...   |
# | chrX         | 131823775 | 131825221 | ...   |
# +--------------+-----------+-----------+-------+
# Stranded PyRanges object has 282 rows and 9 columns from 23 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 6 hidden columns: Name, Score, Strand, gene_name, Feature, ... (+ 1 more.)

# %%
papa_cryp_bed_upd.subset(lambda df: df.gene_name == "ELK1")
# Out:
# +--------------+-----------+-----------+-------+
# | Chromosome   |     Start |       End | +6    |
# | (category)   |   (int64) |   (int64) | ...   |
# |--------------+-----------+-----------+-------|
# | chrX         |  47631618 |  47636927 | ...   |
# | chrX         |  47635520 |  47636927 | ...   |
# +--------------+-----------+-----------+-------+
# Stranded PyRanges object has 2 rows and 9 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 6 hidden columns: Name, Score, Strand, gene_name, Feature, ... (+ 1 more.)
